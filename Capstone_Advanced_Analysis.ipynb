# %%
# Exploratory Analysis of the EEG data; Total features: 178, Class: 1; Instances: 11500
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# reading the data file
eeg = pd.read_csv('eeg_data_1.csv')

# %%
# Information on data file
eeg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11500 entries, 0 to 11499
# Columns: 179 entries, X1 to y
# dtypes: int64(179)
# memory usage: 15.7 MB

# %%
cls = eeg.groupby('y')

# %%
print(cls)
# Out:
# <pandas.core.groupby.DataFrameGroupBy object at 0x000001DA06F0FFD0>

# %%
cls.head()
# Out:
#      X1   X2   X3   X4   X5   X6   X7   X8   X9  X10 ...  X170  X171  X172  \
# 0   135  190  229  223  192  125   55   -9  -33  -38 ...   -17   -15   -31
# 1   386  382  356  331  320  315  307  272  244  232 ...   164   150   146
# 2   -32  -39  -47  -37  -32  -36  -57  -73  -85  -94 ...    57    64    48
# 3  -105 -101  -96  -92  -89  -95 -102 -100  -87  -79 ...   -82   -81   -80
# 4    -9  -65  -98 -102  -78  -48  -16    0  -21  -59 ...     4     2   -12
# 5    55   28   18   16   16   19   25   40   52   66 ...   -12   -31   -42
# 6   -55   -9   52  111  135  129  103   72   37    0 ...  -125   -99   -79
# 7     1   -2   -8  -11  -12  -17  -15  -16  -18  -17 ...   -79   -91   -97
# 8  -278 -246 -215 -191 -177 -167 -157 -139 -118  -92 ...  -400  -379  -336
# 9     8   15   13    3   -6   -8   -5    4   25   41 ...    49    31    11
# 10   -5   15   28   28    9  -29  -41  -19   14   30 ...   -38    -4    25
# 11 -167 -230 -280 -315 -338 -369 -405 -392 -298 -140 ...   423   434   416
# 12   92   49    0  -32  -51  -65  -37  -19  -25  -29 ...   -56   -41   -40
# 13   15   12    0  -17  -28  -31  -39  -51  -44  -35 ...   -88  -102   -97
# 14  -24  -15   -5   -1    4    3    6   10   11    7 ...    32    35    36
# 15 -135 -133 -125 -118 -111 -105 -102  -93  -94  -90 ...   -49   -39   -35
# 16   39   41   41   42   43   43   46   47   49   50 ...    43    41    41
# 17    9    4   -5  -10  -22  -30  -33  -43  -41  -40 ...    34    27    22
# 18  -21   -5    1    7   19   20   13    2   -1   -3 ...    43    28    25
# 19    4   24   51   76   92  102  104  101   90   80 ...     3     5    10
# 20  410  451  491  541  581  641  736  757  692  435 ...   415   428   463
# 21  -24  -27  -23  -28  -34  -40  -47  -43  -38  -23 ...   -81   -51   -38
# 22 -264 -189 -117  -45   20   70  111  143  161  179 ...  -231  -221  -248
# 25  -16  -15  -19  -16  -14   -5    0   -1   -3   -5 ...    56    56    62
# 35   90   60   56   50   -6  -30  -48  -48  -19    9 ...   -50   -51   -48
#
#     X173  X174  X175  X176  X177  X178  y
# 0    -77  -103  -127  -116   -83   -51  4
# 1    152   157   156   154   143   129  1
# 2     19   -12   -30   -35   -35   -36  5
# 3    -77   -85   -77   -72   -69   -65  5
# 4    -32   -41   -65   -83   -89   -73  5
# 5    -54   -60   -64   -60   -56   -55  5
# 6    -62   -41   -26    11    67   128  4
# 7    -88   -76   -72   -66   -57   -39  2
# 8   -281  -226  -174  -125   -79   -40  1
# 9     -5   -17   -19   -15   -15   -11  4
# 10    16   -16   -74  -101   -89   -49  5
# 11   374   319   268   215   165   103  1
# 12   -43   -32   -13    -1    -7   -44  3
# 13   -77   -45   -19    13    44    68  4
# 14    34    32    26    23    18    20  2
# 15   -29   -10     4    21    31    37  3
# 16    43    43    40    41    41    49  2
# 17    18    15    13     9     9     3  3
# 18    19    30    35    26     5   -13  4
# 19    19    31    36    40    43    36  2
# 20   510   562   607   667   748   763  1
# 21   -11   -12     4     5    -4    -3  2
# 22  -321  -444  -530  -548  -536  -486  1
# 25    54    53    53    50    57    54  3
# 35     1    -1    27     2    -6    12  3
#
# [25 rows x 179 columns]

# %%
Mean = cls.mean()

# %%
Std = cls.std()

# %%
Mean
# Out:
#           X1         X2         X3         X4         X5         X6  \
# y
# 1 -21.936522 -19.049130 -15.293913  -9.836087  -3.707391   2.730000
# 2  -7.710000  -8.148696  -8.020000  -8.050435  -7.776957  -8.220870
# 3  -9.207391  -9.276522  -9.968261 -10.634348 -11.172174 -11.559130
# 4 -12.726087 -12.410435 -12.272609 -12.096957 -12.083043 -12.349130
# 5  -6.326957  -5.673043  -5.380870  -5.097391  -5.309130  -5.618261
#
#           X7         X8         X9        X10    ...           X169  \
# y                                                ...
# 1   6.899565   7.425652   8.380870  10.773913    ...      -7.266522
# 2  -8.597826  -9.210000  -9.217826  -9.347826    ...      -7.979565
# 3 -11.797826 -12.013043 -12.132609 -12.249130    ...     -13.590000
# 4 -13.064348 -13.419565 -13.441739 -13.147826    ...     -13.428696
# 5  -5.950000  -6.218696  -6.378696  -6.871304    ...      -5.229565
#
#         X170       X171       X172       X173       X174       X175  \
# y
# 1  -9.714783 -15.909565 -22.383043 -26.424783 -26.221739 -25.830870
# 2  -8.483043  -8.967391  -9.067391  -8.924783  -8.592174  -8.524348
# 3 -13.332174 -13.218696 -12.789565 -12.366087 -11.320000 -10.455217
# 4 -13.636522 -14.114783 -14.404783 -14.251304 -14.109565 -13.653913
# 5  -5.562174  -5.941304  -6.072609  -6.377391  -6.573043  -6.760870
#
#         X176       X177       X178
# y
# 1 -25.043913 -24.548261 -24.016522
# 2  -8.558696  -8.187391  -8.147391
# 3  -9.757391  -9.418696  -8.935217
# 4 -13.082174 -12.791739 -12.914783
# 5  -7.083478  -7.183913  -6.964348
#
# [5 rows x 178 columns]

# %%
Class_1 = Mean[:1]

# %%
Class_1
# Out:
#           X1        X2         X3        X4        X5    X6        X7  \
# y
# 1 -21.936522 -19.04913 -15.293913 -9.836087 -3.707391  2.73  6.899565
#
#          X8       X9        X10    ...          X169      X170       X171  \
# y                                  ...
# 1  7.425652  8.38087  10.773913    ...     -7.266522 -9.714783 -15.909565
#
#         X172       X173       X174      X175       X176       X177       X178
# y
# 1 -22.383043 -26.424783 -26.221739 -25.83087 -25.043913 -24.548261 -24.016522
#
# [1 rows x 178 columns]

# %%
sns.distplot(Class_1)

# %%
Std_1 = Std[:1]

# %%
sns.distplot(Std_1)

# %%
Class_2 = Mean[:2]
Class_3 = Mean[:3]
Class_4 = Mean[:4]
Class_5 = Mean[:5]

# %%
fig, axs = plt.subplots(2, 2, figsize=(5, 5))
axs[0, 0].hist(Class_2)
axs[1, 0].hist(Class_3)
axs[0, 1].hist(Class_4)
axs[1, 1].hist(Class_5)
plt.show()

# %%
sns.stripplot(data=Mean, jitter=True, palette='Set1')

# %%
sns.violinplot(data=Mean, palette='Set1')
